# %%
import tensorflow as tf
import pandas as pd

# %%
mapSizes = [20, 50, 100, 500]
obstacleRatios = [4, 10, 40, 100]
fileName = []

#make csv file names.
for mapSize in mapSizes:
    for obstacleRatio in obstacleRatios:
        fileName.append(str(obstacleRatio) + "_" + str(mapSize) + ".csv")

# %%
df0 = pd.read_csv('../csv/' + fileName[0], encoding = "utf-8")
df0["20x20"] = df0["20x20"].replace("20x20",400)
df0.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df1 = pd.read_csv('../csv/' + fileName[1], encoding = "utf-8")
df1["20x20"] = df1["20x20"].replace("20x20",400)
df1.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df2 = pd.read_csv('../csv/' + fileName[2], encoding = "utf-8")
df2["20x20"] = df2["20x20"].replace("20x20",400)
df2.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df3 = pd.read_csv('../csv/' + fileName[3], encoding = "utf-8")
df3["20x20"] = df3["20x20"].replace("20x20",400)
df3.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]



df4 = pd.read_csv('../csv/' + fileName[4], encoding = "utf-8")
df4["50x50"] = df4["50x50"].replace("50x50",2500)
df4.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df5 = pd.read_csv('../csv/' + fileName[5], encoding = "utf-8")
df5["50x50"] = df5["50x50"].replace("50x50",2500)
df5.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df6 = pd.read_csv('../csv/' + fileName[6], encoding = "utf-8")
df6["50x50"] = df6["50x50"].replace("50x50",2500)
df6.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df7 = pd.read_csv('../csv/' + fileName[7], encoding = "utf-8")
df7["50x50"] = df7["50x50"].replace("50x50",2500)
df7.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]



df8 = pd.read_csv('../csv/' + fileName[8], encoding = "utf-8")
df8["100x100"] = df8["100x100"].replace("100x100",10000)
df8.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df9 = pd.read_csv('../csv/' + fileName[9], encoding = "utf-8")
df9["100x100"] = df9["100x100"].replace("100x100",10000)
df9.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df10 = pd.read_csv('../csv/' + fileName[10], encoding = "utf-8")
df10["100x100"] = df10["100x100"].replace("100x100",10000)
df10.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df11 = pd.read_csv('../csv/' + fileName[11], encoding = "utf-8")
df11["100x100"] = df11["100x100"].replace("100x100",10000)
df11.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]



df12 = pd.read_csv('../csv/' + fileName[12], encoding = "utf-8")
df12["500x500"] = df12["500x500"].replace("500x500",250000)
df12.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df13 = pd.read_csv('../csv/' + fileName[13], encoding = "utf-8")
df13["500x500"] = df13["500x500"].replace("500x500",250000)
df13.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df14 = pd.read_csv('../csv/' + fileName[14], encoding = "utf-8")
df14["500x500"] = df14["500x500"].replace("500x500",250000)
df14.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

df15 = pd.read_csv('../csv/' + fileName[15], encoding = "utf-8")
df15["500x500"] = df15["500x500"].replace("500x500",250000)
df15.columns = ["맵 크기", "장애물 개수", "소요시간(ms)"]

# %%
df = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15])
df
# Out:
#       맵 크기  장애물 개수  소요시간(ms)
# 0      400     100         3
# 1      400     100         1
# 2      400     100         1
# 3      400     100         2
# 4      400     100         2
# ..     ...     ...       ...
# 94  250000    2500         8
# 95  250000    2500         9
# 96  250000    2500         4
# 97  250000    2500        37
# 98  250000    2500         9
#
# [1584 rows x 3 columns]

# %%
dep = df[["맵 크기", "장애물 개수"]]
indep = df[["소요시간(ms)"]]
print(dep.shape, indep.shape)
# Out:
# (1584, 2) (1584, 1)

# %%
X = tf.keras.layers.Input(shape=[2])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
Y = tf.keras.layers.Dense(3, activation = 'softmax')(H)
model = tf.keras.models.Model(X,Y)
model.compile(loss='categorical_crossentropy', metrics='accuracy')

# %%
model.fit(dep, indep, epochs=1000)
# Out:
# Epoch 1/1000
# 50/50 [==============================] - 0s 692us/step - loss: 21294118.0000
# Epoch 2/1000
# 50/50 [==============================] - 0s 672us/step - loss: 21158240.0000
# Epoch 3/1000
# 50/50 [==============================] - 0s 716us/step - loss: 21298226.0000
# Epoch 4/1000
# 50/50 [==============================] - 0s 653us/step - loss: 21098318.0000
# Epoch 5/1000
# 50/50 [==============================] - 0s 677us/step - loss: 21174284.0000
# Epoch 6/1000
# 50/50 [==============================] - 0s 649us/step - loss: 21152200.0000
# Epoch 7/1000
# 50/50 [==============================] - 0s 726us/step - loss: 21142330.0000
# Epoch 8/1000
# 50/50 [==============================] - 0s 766us/step - loss: 21244390.0000
# Epoch 9/1000
# 50/50 [==============================] - 0s 927us/step - loss: 20867060.0000
# Epoch 10/1000
# 50/50 [==============================] - 0s 762us/step - loss: 21464374.0000
# Epoch 11/1000
# ...

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# ...
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 데이터가 실제로도 표준편차가 매우 큰 데이터이다. loss 가 너무크다. 그만 알아보도록 하자.
